# %%
from read import read_obs as ro
from plot import plot_obs as po

def main(directory, obstype, filetype, var, savename):
    obs_data = []
    # Read observations based on provided arguments
    try:
        obs_data = ro.read_obs(directory, obstype, filetype)
        print("Successfully read data.")
    except Exception as e:
        print(f"An error occurred: {e}")

    # Read observations based on provided arguments
    try:
        plot = po.plot_obs(obs_data, obstype, var, savename)
        
        print("Successfully plotted data. Check figures directory for output.")
    except Exception as e:
        print(f"An error occurred: {e}")

# %%
main('./demo/', 'WOD', 'nc', 'sla_filtered', 'sla_filtered_map')
# Out:
# Successfully read data.
# Successfully plotted data. Check figures directory for output.
